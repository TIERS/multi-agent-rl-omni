# %%
print("Hello world!")
# Out:
# Hello world!

# %%
import bagpy
from bagpy import bagreader
import pandas as pd
import seaborn as sea
import matplotlib.pyplot as plt
import numpy as np

# %%
pd.set_option('display.max_rows', 80)

# %%
b = bagreader("/home/eetu/rosbags/thesis/experiment1/ex1_p1_baseline_2023-07-13-12-59-58.bag")
# Out:
# [INFO]  Successfully created the data folder /home/eetu/rosbags/thesis/experiment1/ex1_p1_baseline_2023-07-13-12-59-58.

# %%
b.topic_table
# Out:
#                                                Topics  \
# 0                                        /diagnostics
# 1                                    /diagnostics_agg
# 2                         /diagnostics_toplevel_state
# 3                          /execute_trajectory/status
# 4               /franka_control/error_recovery/status
# 5                        /franka_gripper/grasp/status
# 6               /franka_gripper/gripper_action/status
# 7                       /franka_gripper/homing/status
# 8                        /franka_gripper/joint_states
# 9                         /franka_gripper/move/status
# 10                        /franka_gripper/stop/status
# 11                     /franka_state_controller/F_ext
# 12             /franka_state_controller/franka_states
# 13              /franka_state_controller/joint_states
# 14      /franka_state_controller/joint_states_desired
# 15                                     /husky/cmd_vel
# ...

# %%
targets = b.message_by_topic('/target')

# %%
pd.read_csv(targets)
# Out:
#              Time  header.seq  header.stamp.secs  header.stamp.nsecs  \
# 0    1.689242e+09           1         1689242408           294579505
# 1    1.689242e+09           2         1689242408           358338117
# 2    1.689242e+09           3         1689242408           409166574
# 3    1.689242e+09           4         1689242408           500354528
# 4    1.689242e+09           5         1689242408           541085481
# ..            ...         ...                ...                 ...
# 964  1.689242e+09         965         1689242465           589562416
# 965  1.689242e+09         966         1689242465           630262851
# 966  1.689242e+09         967         1689242465           660884380
# 967  1.689242e+09         968         1689242465           694340467
# 968  1.689242e+09         969         1689242465           788386106
#
#     header.frame_id   point.x    point.y  point.z
# 0          universe  3.215198  10.385247  0.47312
# ...
